# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.model_selection import train_test_split,cross_val_score
from statistics import mean

# %%
df=pd.read_csv('D:\\Machine Learning\\kc_house_data.csv')
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
y=df['price']
x=df['bedrooms'].values.reshape(-1,1)

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.4)

# %%
Linear_model=LinearRegression()

# %%
Linear_model.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
Linear_model.score(X_test,y_test)
# Out:
# 0.10183044442989342

# %%
cross_val_score_ridge=[]
alpha=[]

# %%
for i in range(1,9):
    ridgeModel=Ridge(alpha=i*0.25)
    ridgeModel.fit(X_train,y_train)
    scores=cross_val_score(ridgeModel,x,y,cv=10)
    avg_cross_val_score=mean(scores)*100
    cross_val_score_ridge.append(avg_cross_val_score)
    alpha.append(i*0.25)

# %%
for i in range(0,len(alpha)):
    print(str(alpha[i])+':'+str(cross_val_score_ridge[i]))
# Out:
# 0.25:9.161769919450649
# 0.5:9.161774802094591
# 0.75:9.161779680233046
# 1.0:9.16178455386642
# 1.25:9.16178942299511
# 1.5:9.161794287619497
# 1.75:9.161799147739998
# 2.0:9.161804003357

# %%
cross_val_score_lasso=[]
alpha1=[]

# %%
for i in range(1,10):
    lassoModel=Lasso(alpha=i*0.25)
    lassoModel.fit(X_train,y_train)
    scores=cross_val_score(lassoModel,x,y,cv=10)
    avg_cross_val_score=mean(scores)*100
    cross_val_score_lasso.append(cross_val_score)
    alpha1.append(i*0.25)

# %%
for i in range(0,len(alpha1)):
    print(str(alpha1[i])+':'+str(cross_val_score_lasso[i]))
# Out:
# 0.25:<function cross_val_score at 0x0000022389F689D8>
# 0.5:<function cross_val_score at 0x0000022389F689D8>
# 0.75:<function cross_val_score at 0x0000022389F689D8>
# 1.0:<function cross_val_score at 0x0000022389F689D8>
# 1.25:<function cross_val_score at 0x0000022389F689D8>
# 1.5:<function cross_val_score at 0x0000022389F689D8>
# 1.75:<function cross_val_score at 0x0000022389F689D8>
# 2.0:<function cross_val_score at 0x0000022389F689D8>
# 2.25:<function cross_val_score at 0x0000022389F689D8>
# 0.25:<function cross_val_score at 0x0000022389F689D8>
# 0.5:<function cross_val_score at 0x0000022389F689D8>
# 0.75:<function cross_val_score at 0x0000022389F689D8>
# 1.0:<function cross_val_score at 0x0000022389F689D8>
# 1.25:<function cross_val_score at 0x0000022389F689D8>
# 1.5:<function cross_val_score at 0x0000022389F689D8>
# 1.75:<function cross_val_score at 0x0000022389F689D8>
# 2.0:<function cross_val_score at 0x0000022389F689D8>
# 2.25:<function cross_val_score at 0x0000022389F689D8>
